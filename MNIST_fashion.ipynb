# %%
# importing modules.
import torch
import torch.nn.functional as F
import numpy as np
from torch import nn, optim
from torchvision import transforms, datasets

# %%
# defining transforms for images.
transform = transforms.Compose([transforms.ToTensor()])

# %%
# Loading data from dataset

# Training Data
train_data = datasets.FashionMNIST('fashion_data', train=True, download=True, transform=transform)

#Testing Data
test_data = datasets.FashionMNIST('fashion_data', train=False, download=True, transform=transform)

# %%
# Spliting train data index into train and validation
num_train = len(train_data)
idxs = list(range(num_train))
np.random.shuffle(idxs)

# using 20% of train data for validation.
split = int(np.floor(0.2 * num_train))
train_idx = idxs[split:]
valid_idx = idxs[:split]

# %%
# samplers to obtain indices for batches.
train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
valid_sampler = torch.utils.data.SubsetRandomSampler(valid_idx)

# %%
# defining loader to load data in batches.
# defining batch size
batch_size = 20

# Training loader
train_loader = torch.utils.data.DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# Validation loader
valid_loader = torch.utils.data.DataLoader(train_data, sampler=valid_sampler, batch_size=batch_size)

# testing loader
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True)

classes = ['T-shirt/top',
            'Trouser',
            'Pullover',
            'Dress',
            'Coat',
            'Sandal',
            'Shirt',
            'Sneaker',
            'Bag',
            'Ankle Boot']

# %%
# Now let's see the data we loaded visually.
# import matplot library
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# taking one batch from train_loader 
images, labels = iter(train_loader).next()

# converting images from tensor to numpy array just for visulization. 
images = images.numpy()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for i in range(20):
    ax = fig.add_subplot(2, 20/2, i + 1, xticks=[], yticks=[])
    ax.set_title(classes[labels[i].item()])
    ax.imshow(np.squeeze(images[i]), cmap='gray')

# %% [markdown]
# ## Defining network architecture.
# Each image is **28 X 28** means if we flatten the image it will be 784 px. Thus input layer will have **784 units**.The number of digits 0-9, **10** output for output layer.
#
# * Input Layer
#
#     * 784 input units, 128 output units.
#
#
# * hidden Layer 1
#
#     * 128 input units, 64 output units.
#
#
# * hidden Layer 2
#
#     * 64 input units, 32 output units.
#
#
# * hidden Layer 3
#
#     * 32 input units, 16 output units.
#
#
# * output Layer
#
#     * 16 input units, 10 output units.
#
# Activation function : _Relu_
#
# Dropout with p=0.2

# %%
# Defining network architecture.
class Network(nn.Module):
    
    def __init__(self):
        
        super().__init__()
        # Input layer: 784 => 128.
        self.fc1 = nn.Linear(784, 128)
        
        # Hidden layer 1: 128 => 64.
        self.fc2 = nn.Linear(128, 64)
        
        # Hidden Layer 2: 64 => 32.
        self.fc3 = nn.Linear(64, 32)
        
        # Hidden Layer 3: 32 => 16.
        self.fc4 = nn.Linear(32, 16)
        
        # Output layer: 16 => 10.
        self.fc5 = nn.Linear(16, 10)
        
        # Defining dropout with p = 0.2
        self.dropout = nn.Dropout(p=0.2)
        
    def forward(self, X):
        
        # Flatten inputs.
        X = X.view(-1, 784)
        
        # Input Layer.
        X = self.dropout(F.relu(self.fc1(X)))
        
        # Hidden Layer 1
        X = self.dropout(F.relu(self.fc2(X)))
        
        # Hidden Layer 2
        X = self.dropout(F.relu(self.fc3(X)))
        
        # Hidden Layer 3
        X = self.dropout(F.relu(self.fc4(X)))
        
        # Output Layer with log_sofmax function.
        X = F.log_softmax(self.fc5(X), dim=1)
        
        return X

# %%
# Instance of Network
model = Network()
model
# Out:
# Network(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=16, bias=True)
#   (fc5): Linear(in_features=16, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %%
# Defining optimzer and loss function.
# Loss function : NLLLoss
criterion = nn.CrossEntropyLoss()

# # optimzer Adam
optimizer = optim.SGD(model.parameters(), lr=0.001)

# %%
# training model

# Epochs for training.
epochs = 50

# defining min_valid loss to np.inf
valid_min = np.inf

for i in range(epochs):
    
    # set model for training.
    model.train()
    
    # defining train loss and validation loss to 0.0 later we calculate using loss function.
    train_loss = 0.0
    valid_loss = 0.0
    
    for images, labels in train_loader:
        
        # cleaning gradient for all optimized variables.
        optimizer.zero_grad()
        
        # forwardpass passing images to model
        output = model(images)
        
        # Calculating loss to perform backward pass
        loss = criterion(output, labels)
        
        # backward pass compute loss with resp to parameters.
        loss.backward()
        
        # optimizer single step.
        optimizer.step()
        
        # updating total loss
        train_loss += loss.item() * images.size(0)
        
    # set model for evalutaion.
    model.eval()
    
    # validating model.
    for images, labels in valid_loader:
        
         # forwardpass passing images to model
        output = model(images)
        
        # Calculating loss to perform backward pass
        loss = criterion(output, labels)
        
        # Updating total validation loss.
        valid_loss += loss.item() * images.size(0)
        
    train_loss = train_loss / len(train_loader.dataset)
    valid_loss = valid_loss / len(valid_loader.dataset)
    
    print("Training loss:", train_loss, "\tValidation loss:", valid_loss, "\tEpoch:", str(i+1))
    
    if valid_loss <= valid_min:
        print("Saving model.")
        torch.save(model.state_dict(), 'model_fashion.pth')
        valid_min = valid_loss
# Out:
# Training loss: 1.8429928455352784 	Validation loss: 0.4595106303691864 	Epoch: 1
# Saving model.
# Training loss: 1.8312711044947307 	Validation loss: 0.45446315709749857 	Epoch: 2
# Saving model.
# Training loss: 1.7941051737467448 	Validation loss: 0.4362739183902741 	Epoch: 3
# Saving model.
# Training loss: 1.6993368319670359 	Validation loss: 0.405192749897639 	Epoch: 4
# Saving model.
# Training loss: 1.6018692868153255 	Validation loss: 0.38309662775198616 	Epoch: 5
# Saving model.
# Training loss: 1.5210250727732977 	Validation loss: 0.35916834783554075 	Epoch: 6
# Saving model.
# Training loss: 1.412129314382871 	Validation loss: 0.3165326229731242 	Epoch: 7
# Saving model.
# Training loss: 1.2559490178028743 	Validation loss: 0.26666890263557436 	Epoch: 8
# Saving model.
# Training loss: 1.1387474526365597 	Validation loss: 0.24590460016330082 	Epoch: 9
# Saving model.
# Training loss: 1.0802596998413403 	Validation loss: 0.23460701104005177 	Epoch: 10
# Saving model.
# Training loss: 1.0394882594943047 	Validation loss: 0.22618302458524703 	Epoch: 11
# Saving model.
# Training loss: 1.0064669973055522 	Validation loss: 0.2181867042382558 	Epoch: 12
# Saving model.
# Training loss: 0.9705789980689684 	Validation loss: 0.21046097284555434 	Epoch: 13
# Saving model.
# Training loss: 0.9461977853973706 	Validation loss: 0.20404588065544765 	Epoch: 14
# Saving model.
# Training loss: 0.9195071978767713 	Validation loss: 0.1975907370845477 	Epoch: 15
# Saving model.
# Training loss: 0.8965539611577987 	Validation loss: 0.19147124820947647 	Epoch: 16
# Saving model.
# Training loss: 0.8755110181967417 	Validation loss: 0.18736063035329184 	Epoch: 17
# Saving model.
# Training loss: 0.8564286228219669 	Validation loss: 0.1830668717424075 	Epoch: 18
# Saving model.
# Training loss: 0.8475322144826253 	Validation loss: 0.1800133034090201 	Epoch: 19
# Saving model.
# Training loss: 0.8286039022902648 	Validation loss: 0.17628150715430577 	Epoch: 20
# Saving model.
# Training loss: 0.8163887818455696 	Validation loss: 0.17345377217729888 	Epoch: 21
# Saving model.
# Training loss: 0.8051098280549049 	Validation loss: 0.17131663461526234 	Epoch: 22
# Saving model.
# Training loss: 0.7889447710116704 	Validation loss: 0.16836163626114528 	Epoch: 23
# Saving model.
# Training loss: 0.7817721854249636 	Validation loss: 0.16560395634174346 	Epoch: 24
# Saving model.
# Training loss: 0.7713621843556563 	Validation loss: 0.16369394420584044 	Epoch: 25
# Saving model.
# Training loss: 0.7566755894223849 	Validation loss: 0.16085659925142923 	Epoch: 26
# Saving model.
# Training loss: 0.7532992314994336 	Validation loss: 0.15902392279108366 	Epoch: 27
# Saving model.
# Training loss: 0.7428613284329574 	Validation loss: 0.157443640679121 	Epoch: 28
# Saving model.
# Training loss: 0.7308579286237558 	Validation loss: 0.15486865030725797 	Epoch: 29
# Saving model.
# Training loss: 0.7211184987723828 	Validation loss: 0.15325324082374572 	Epoch: 30
# Saving model.
# Training loss: 0.7113772199849288 	Validation loss: 0.15088023954629898 	Epoch: 31
# Saving model.
# Training loss: 0.7043969983955224 	Validation loss: 0.14923391780257225 	Epoch: 32
# Saving model.
# Training loss: 0.6980034702519575 	Validation loss: 0.1473574904203415 	Epoch: 33
# Saving model.
# Training loss: 0.6906300019224485 	Validation loss: 0.14542977772156399 	Epoch: 34
# Saving model.
# Training loss: 0.6837150298655034 	Validation loss: 0.14432438693443933 	Epoch: 35
# Saving model.
# Training loss: 0.6769646402498086 	Validation loss: 0.14259047770500183 	Epoch: 36
# Saving model.
# Training loss: 0.6701838436623414 	Validation loss: 0.14123574179410933 	Epoch: 37
# Saving model.
# Training loss: 0.6611034451127052 	Validation loss: 0.13983535388112067 	Epoch: 38
# Saving model.
# Training loss: 0.6558429182122151 	Validation loss: 0.13853581130504608 	Epoch: 39
# Saving model.
# Training loss: 0.6452831997374694 	Validation loss: 0.13643187602361043 	Epoch: 40
# Saving model.
# Training loss: 0.6411190323134264 	Validation loss: 0.1352915330082178 	Epoch: 41
# Saving model.
# Training loss: 0.6349961839417616 	Validation loss: 0.13364579861362774 	Epoch: 42
# Saving model.
# Training loss: 0.6292780370215575 	Validation loss: 0.1325565225581328 	Epoch: 43
# Saving model.
# Training loss: 0.627031983345747 	Validation loss: 0.13154819611211618 	Epoch: 44
# Saving model.
# Training loss: 0.6181715754171212 	Validation loss: 0.13066311219334603 	Epoch: 45
# Saving model.
# Training loss: 0.6122696494261424 	Validation loss: 0.12876573130488395 	Epoch: 46
# Saving model.
# Training loss: 0.6068286338150501 	Validation loss: 0.12812910107771555 	Epoch: 47
# Saving model.
# Training loss: 0.6029162331024805 	Validation loss: 0.1261955635448297 	Epoch: 48
# Saving model.
# Training loss: 0.5960709283898274 	Validation loss: 0.12505205064018568 	Epoch: 49
# Saving model.
# Training loss: 0.5916051846643289 	Validation loss: 0.12345314985513688 	Epoch: 50
# Saving model.

# %%
# Testing Model.
# Initilizing list to moniter test and accuracy.
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

# prepate mode for evalution.
model.eval()

for images, labels in test_loader:
    
    # forwardpass passing images to model
    output = model(images)
    
    # calculate the loss
    loss = criterion(output, labels)
    
    # update test loss 
    test_loss += loss.item() * images.size(0)
    
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    
    # compare predictions to true label
    correct = np.squeeze(pred.eq(labels.data.view_as(pred)))
    
     # calculate test accuracy for each object class
    for i in range(batch_size):
        
        label = labels.data[i]
        
        class_correct[label] += correct[i].item()
        
        class_total[label] += 1
        
# calculate and print avg test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: \t %2d%% (%2d/%2d)' % (
            str(classes[i]), 100 * class_correct[i]/ class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.625388
#
# Test Accuracy of T-shirt/top: 	 83% (837/1000)
# Test Accuracy of Trouser: 	 94% (946/1000)
# Test Accuracy of Pullover: 	 69% (698/1000)
# Test Accuracy of Dress: 	 81% (819/1000)
# Test Accuracy of  Coat: 	 71% (716/1000)
# Test Accuracy of Sandal: 	 84% (844/1000)
# Test Accuracy of Shirt: 	 11% (112/1000)
# Test Accuracy of Sneaker: 	 91% (912/1000)
# Test Accuracy of   Bag: 	 94% (941/1000)
# Test Accuracy of Ankle Boot: 	 94% (944/1000)
#
# Test Accuracy (Overall): 77% (7769/10000)

# %%
# Visualize data with test result.
# obtain one batch of test images
dataiter = iter(test_loader)

# %%
images, labels = dataiter.next()

# get sample outputs
output = model(images)

# convert output probabilities to predicted class
_, preds = torch.max(output, 1)

# prep images for display
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(20):
    
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    
    ax.set_title("{} ({})".format(str(classes[preds[idx].item()]), str(classes[labels[idx].item()])),
                 color=("green" if preds[idx]==labels[idx] else "red"))
